# %% [markdown]
# ## Load required packages

# %%
using Pkg # import the Pkg module so we can use other packages
Pkg.add("CSV") # install CSV package so we can work with the data provided in a CSV file
Pkg.add("DataFrames") # install to allow to change and analyse the dataframes
Pkg.add("Dates") # install dates package to convert strings to date
Pkg.add("Statistics") # to calculate stats
Pkg.add("Query") # for analysing the data
Pkg.add("Plots") # for plotting
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\diann\.julia\environments\v1.9\Manifest.toml`

# %% [markdown]
# ## Load the data

# %%
using CSV # import to use CSV package
using DataFrames # import to use DataFrames package

NZ_cost = CSV.read("NZ_average_price_25_pack_cigarettes.csv", DataFrame) # average price dataset from StatsNZ
NZ_prev = CSV.read("NZ_smoking_prevalence_1983_2017.csv", DataFrame) # smoking prevalence dataset from Tobacco Control Data Repository
NZ_health = CSV.read("NZ_Mortality_Cancer_Trends.csv", DataFrame) # mortality rates dataset from University of Otago
NZ_recent = CSV.read("nz-health-survey-2021-22-prevalences.csv", DataFrame) #smoking prevalence dataset from MOH
# Out:
# 30760×19 DataFrame
#    Row │ population  short.description                  year   group           ⋯
#        │ String      String                             Int64  String          ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ adults      Excellent, very good or good sel…   2021  Total           ⋯
#      2 │ adults      Excellent, very good or good sel…   2021  15-24
#      3 │ adults      Excellent, very good or good sel…   2021  25-34
#      4 │ adults      Excellent, very good or good sel…   2021  35-44
#      5 │ adults      Excellent, very good or good sel…   2021  45-54           ⋯
#      6 │ adults      Excellent, very good or good sel…   2021  55-64
#      7 │ adults      Excellent, very good or good sel…   2021  65-74
#      8 │ adults      Excellent, very good or good sel…   2021  75+
#      9 │ adults      Excellent, very good or good sel…   2021  Māori           ⋯
#     10 │ adults      Excellent, very good or good sel…   2021  Pacific
#     11 │ adults      Excellent, very good or good sel…   2021  Asian
#    ⋮   │     ⋮                       ⋮                    ⋮          ⋮         ⋱
#  30751 │ children    Private health insurance            2019  Quintile 1
#  30752 │ children    Private health insurance            2019  Quintile 2      ⋯
#  30753 │ children    Private health insurance            2019  Quintile 3
#  30754 │ children    Private health insurance            2019  Quintile 4
#  30755 │ children    Private health insurance            2019  Quintile 5
#  30756 │ children    Private health insurance            2020  Quintile 1      ⋯
#  30757 │ children    Private health insurance            2020  Quintile 2
#  30758 │ children    Private health insurance            2020  Quintile 3
#  30759 │ children    Private health insurance            2020  Quintile 4
#  30760 │ children    Private health insurance            2020  Quintile 5      ⋯
#                                                15 columns and 30739 rows omitted

# %% [markdown]
# ## Wrangling NZ_prev

# %%
NZ_prev # see what it looks like
# Out:
# 35×4 DataFrame
#  Row │ Year   Adults 15+ years (current smoking)  Year 10 students (current sm ⋯
#      │ Int64  String                              String                       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  1983  33                                  null                         ⋯
#    2 │  1984  32                                  null
#    3 │  1985  30                                  null
#    4 │  1986  30                                  null
#    5 │  1987  30                                  null                         ⋯
#    6 │  1988  29                                  null
#    7 │  1989  26.5                                null
#    8 │  1990  27.8                                null
#    9 │  1991  25.8                                null                         ⋯
#   10 │  1992  27                                  null
#   11 │  1993  27                                  null
#   ⋮  │   ⋮                    ⋮                                   ⋮            ⋱
#   26 │  2008  21                                  11.9
#   27 │  2009  19.7                                10.9                         ⋯
#   28 │  2010  19.7                                10
#   29 │  2011  18.4                                8.2
#   30 │  2012  17.6                                7.7
#   31 │  2013  17.4                                6.8                          ⋯
#   32 │  2014  16.6                                6.1
#   33 │  2015  16.3                                5.4
#   34 │  2016  15.7                                4.7
#   35 │  2017  null                                4.9                          ⋯
#                                                    2 columns and 14 rows omitted

# %%
select!(NZ_prev, Not([:"Year 10 students (current smoking)", "Column4"])) # delete unecessary columns

rename!(NZ_prev, [:Year, :prevalence]) # rename columns

filter!(row -> row.prevalence != "null", NZ_prev) # delete row with null value (2017)
# Out:
# 34×2 DataFrame
#  Row │ Year   prevalence
#      │ Int64  String
# ─────┼───────────────────
#    1 │  1983  33
#    2 │  1984  32
#    3 │  1985  30
#    4 │  1986  30
#    5 │  1987  30
#    6 │  1988  29
#    7 │  1989  26.5
#    8 │  1990  27.8
#    9 │  1991  25.8
#   10 │  1992  27
#   11 │  1993  27
#   ⋮  │   ⋮        ⋮
#   25 │  2007  20
#   26 │  2008  21
#   27 │  2009  19.7
#   28 │  2010  19.7
#   29 │  2011  18.4
#   30 │  2012  17.6
#   31 │  2013  17.4
#   32 │  2014  16.6
#   33 │  2015  16.3
#   34 │  2016  15.7
#           13 rows omitted

# %% [markdown]
# ## Wrangling NZ_cost

# %%
NZ_cost # see what it looks like
# Out:
# 41×2 DataFrame
#  Row │ DateTime   Price per pack of 25 ($)
#      │ String     Float64
# ─────┼─────────────────────────────────────
#    1 │ 1/03/2009                     13.43
#    2 │ 1/06/2009                     13.43
#    3 │ 1/09/2009                     13.32
#    4 │ 1/12/2009                     13.28
#    5 │ 1/03/2010                     13.46
#    6 │ 1/06/2010                     14.31
#    7 │ 1/09/2010                     14.73
#    8 │ 1/12/2010                     15.02
#    9 │ 1/03/2011                     16.39
#   10 │ 1/06/2011                     16.39
#   11 │ 1/09/2011                     16.39
#   ⋮  │     ⋮                 ⋮
#   32 │ 1/12/2016                     28.82
#   33 │ 1/03/2017                     31.6
#   34 │ 1/06/2017                     31.63
#   35 │ 1/09/2017                     31.69
#   36 │ 1/12/2017                     31.68
#   37 │ 1/03/2018                     35.14
#   38 │ 1/06/2018                     35.19
#   39 │ 1/09/2018                     35.17
#   40 │ 1/12/2018                     34.57
#   41 │ 1/03/2019                     37.48
#                             20 rows omitted

# %%
rename!(NZ_cost, [:date, :cost]) # rename variables
# Out:
# 41×2 DataFrame
#  Row │ date       cost
#      │ String     Float64
# ─────┼────────────────────
#    1 │ 1/03/2009    13.43
#    2 │ 1/06/2009    13.43
#    3 │ 1/09/2009    13.32
#    4 │ 1/12/2009    13.28
#    5 │ 1/03/2010    13.46
#    6 │ 1/06/2010    14.31
#    7 │ 1/09/2010    14.73
#    8 │ 1/12/2010    15.02
#    9 │ 1/03/2011    16.39
#   10 │ 1/06/2011    16.39
#   11 │ 1/09/2011    16.39
#   ⋮  │     ⋮         ⋮
#   32 │ 1/12/2016    28.82
#   33 │ 1/03/2017    31.6
#   34 │ 1/06/2017    31.63
#   35 │ 1/09/2017    31.69
#   36 │ 1/12/2017    31.68
#   37 │ 1/03/2018    35.14
#   38 │ 1/06/2018    35.19
#   39 │ 1/09/2018    35.17
#   40 │ 1/12/2018    34.57
#   41 │ 1/03/2019    37.48
#            20 rows omitted

# %%
using Dates
using Statistics

NZ_cost.date = Date.(NZ_cost.date, "dd/mm/yyyy") # convert to date so we can extract year

NZ_cost[!, :Year] = Dates.year.(NZ_cost[!, :date]) # pulls year as int64

cost_df = combine(groupby(NZ_cost, :Year), :cost => mean) # new df with variables year and cost_mean which is the average price per year
# Out:
# 11×2 DataFrame
#  Row │ Year   cost_mean
#      │ Int64  Float64
# ─────┼──────────────────
#    1 │  2009    13.365
#    2 │  2010    14.38
#    3 │  2011    16.39
#    4 │  2012    18.46
#    5 │  2013    20.79
#    6 │  2014    23.0725
#    7 │  2015    26.425
#    8 │  2016    28.805
#    9 │  2017    31.65
#   10 │  2018    35.0175
#   11 │  2019    37.48

# %% [markdown]
# ## Join tables + tidy

# %%
joined_df = outerjoin(cost_df, NZ_prev, on = :Year) # outer join to combine prevalence and cost data with 'year' as the common column. Outer join keeping all data.
# Out:
# 37×3 DataFrame
#  Row │ Year   cost_mean     prevalence
#      │ Int64  Float64?      String?
# ─────┼─────────────────────────────────
#    1 │  2009       13.365   19.7
#    2 │  2010       14.38    19.7
#    3 │  2011       16.39    18.4
#    4 │  2012       18.46    17.6
#    5 │  2013       20.79    17.4
#    6 │  2014       23.0725  16.6
#    7 │  2015       26.425   16.3
#    8 │  2016       28.805   15.7
#    9 │  2017       31.65    missing
#   10 │  2018       35.0175  missing
#   11 │  2019       37.48    missing
#   ⋮  │   ⋮         ⋮            ⋮
#   28 │  1999  missing       26
#   29 │  2000  missing       25
#   30 │  2001  missing       25
#   31 │  2002  missing       25
#   32 │  2003  missing       25
#   33 │  2004  missing       22.8
#   34 │  2005  missing       23.7
#   35 │  2006  missing       20.4
#   36 │  2007  missing       20
#   37 │  2008  missing       21
#                         16 rows omitted

# %%
# function that changes missing values to NaN and converts string to float
function custom_parse_float(x)
    try
        return parse(Float64, x)
    catch
        return NaN
    end
end
# Out:
# custom_parse_float (generic function with 1 method)

# %%
joined_df[!, :prev_float] = [custom_parse_float(x) for x in joined_df[!, :prevalence]] # create new column with Float64 values, replacing missing with NaN
joined_df[!, :cost_mean] .= coalesce.(joined_df[!, :cost_mean], NaN) # change missing values in the "cost_mean" column to NaN
# Out:
# 37-element Vector{Float64}:
#   13.365
#   14.379999999999999
#   16.39
#   18.46
#   20.79
#   23.072499999999998
#   26.425000000000004
#   28.805
#   31.65
#   35.0175
#   37.48
#  NaN
#  NaN
#    ⋮
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN

# %%
select!(joined_df, Not([:prevalence])) # remove prevalence (string) column
# Out:
# 37×3 DataFrame
#  Row │ Year   cost_mean  prev_float
#      │ Int64  Float64    Float64
# ─────┼──────────────────────────────
#    1 │  2009    13.365         19.7
#    2 │  2010    14.38          19.7
#    3 │  2011    16.39          18.4
#    4 │  2012    18.46          17.6
#    5 │  2013    20.79          17.4
#    6 │  2014    23.0725        16.6
#    7 │  2015    26.425         16.3
#    8 │  2016    28.805         15.7
#    9 │  2017    31.65         NaN
#   10 │  2018    35.0175       NaN
#   11 │  2019    37.48         NaN
#   ⋮  │   ⋮        ⋮          ⋮
#   28 │  1999   NaN             26.0
#   29 │  2000   NaN             25.0
#   30 │  2001   NaN             25.0
#   31 │  2002   NaN             25.0
#   32 │  2003   NaN             25.0
#   33 │  2004   NaN             22.8
#   34 │  2005   NaN             23.7
#   35 │  2006   NaN             20.4
#   36 │  2007   NaN             20.0
#   37 │  2008   NaN             21.0
#                      16 rows omitted

# %% [markdown]
# ## Wrangle NZ_recent

# %%
NZ_recent # see what it looks like
# Out:
# 30760×19 DataFrame
#    Row │ population  short.description                  year   group           ⋯
#        │ String      String                             Int64  String          ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ adults      Excellent, very good or good sel…   2021  Total           ⋯
#      2 │ adults      Excellent, very good or good sel…   2021  15-24
#      3 │ adults      Excellent, very good or good sel…   2021  25-34
#      4 │ adults      Excellent, very good or good sel…   2021  35-44
#      5 │ adults      Excellent, very good or good sel…   2021  45-54           ⋯
#      6 │ adults      Excellent, very good or good sel…   2021  55-64
#      7 │ adults      Excellent, very good or good sel…   2021  65-74
#      8 │ adults      Excellent, very good or good sel…   2021  75+
#      9 │ adults      Excellent, very good or good sel…   2021  Māori           ⋯
#     10 │ adults      Excellent, very good or good sel…   2021  Pacific
#     11 │ adults      Excellent, very good or good sel…   2021  Asian
#    ⋮   │     ⋮                       ⋮                    ⋮          ⋮         ⋱
#  30751 │ children    Private health insurance            2019  Quintile 1
#  30752 │ children    Private health insurance            2019  Quintile 2      ⋯
#  30753 │ children    Private health insurance            2019  Quintile 3
#  30754 │ children    Private health insurance            2019  Quintile 4
#  30755 │ children    Private health insurance            2019  Quintile 5
#  30756 │ children    Private health insurance            2020  Quintile 1      ⋯
#  30757 │ children    Private health insurance            2020  Quintile 2
#  30758 │ children    Private health insurance            2020  Quintile 3
#  30759 │ children    Private health insurance            2020  Quintile 4
#  30760 │ children    Private health insurance            2020  Quintile 5      ⋯
#                                                15 columns and 30739 rows omitted

# %%
using Query
columns_keep = ["short.description", "year", "group", "total"] # define columns we want
NZ_recent = select(NZ_recent, Symbol.(columns_keep)) # rewrite df with only wanted columns

NZ_recent = filter(row -> row."short.description" == "Current smokers" && row.group == "Total", NZ_recent) # filter for only current smokers and total (rather than including ethnicity, etc)

columns_keep = ["year", "total"] # define columns we want
NZ_recent = select(NZ_recent, Symbol.(columns_keep)) # rewrite df with only columns we want

rename!(NZ_recent, [:Year, :recent_prev]) # rename columns
# Out:
# 11×2 DataFrame
#  Row │ Year   recent_prev
#      │ Int64  String
# ─────┼────────────────────
#    1 │  2021  9.2
#    2 │  2011  18.4
#    3 │  2012  17.9
#    4 │  2013  17.6
#    5 │  2014  16.8
#    6 │  2015  16.6
#    7 │  2016  16
#    8 │  2017  15.1
#    9 │  2018  14.7
#   10 │  2019  13.7
#   11 │  2020  10.9

# %% [markdown]
# ## Join tables

# %%
joined_df_2 = outerjoin(joined_df, NZ_recent, on = :Year) # join tables on year column
# Out:
# 39×4 DataFrame
#  Row │ Year   cost_mean     prev_float  recent_prev
#      │ Int64  Float64?      Float64?    String?
# ─────┼──────────────────────────────────────────────
#    1 │  2011       16.39          18.4  18.4
#    2 │  2012       18.46          17.6  17.9
#    3 │  2013       20.79          17.4  17.6
#    4 │  2014       23.0725        16.6  16.8
#    5 │  2015       26.425         16.3  16.6
#    6 │  2016       28.805         15.7  16
#    7 │  2017       31.65         NaN    15.1
#    8 │  2018       35.0175       NaN    14.7
#    9 │  2019       37.48         NaN    13.7
#   10 │  2009       13.365         19.7  missing
#   11 │  2010       14.38          19.7  missing
#   ⋮  │   ⋮         ⋮            ⋮            ⋮
#   30 │  2001      NaN             25.0  missing
#   31 │  2002      NaN             25.0  missing
#   32 │  2003      NaN             25.0  missing
#   33 │  2004      NaN             22.8  missing
#   34 │  2005      NaN             23.7  missing
#   35 │  2006      NaN             20.4  missing
#   36 │  2007      NaN             20.0  missing
#   37 │  2008      NaN             21.0  missing
#   38 │  2021  missing        missing    9.2
#   39 │  2020  missing        missing    10.9
#                                      18 rows omitted

# %%
joined_df_2[!, :recent_prev] = [custom_parse_float(x) for x in joined_df_2[!, :recent_prev]] # convert string to float and replace missing with NaN using previous function 

cols_replace = [:cost_mean, :prev_float] # replace missing values with NaN
for col in cols_replace
    joined_df_2[!, col] .= coalesce.(joined_df_2[!, col], NaN)
end

joined_df_2
# Out:
# 39×4 DataFrame
#  Row │ Year   cost_mean  prev_float  recent_prev
#      │ Int64  Float64    Float64     Float64
# ─────┼───────────────────────────────────────────
#    1 │  2011    16.39          18.4         18.4
#    2 │  2012    18.46          17.6         17.9
#    3 │  2013    20.79          17.4         17.6
#    4 │  2014    23.0725        16.6         16.8
#    5 │  2015    26.425         16.3         16.6
#    6 │  2016    28.805         15.7         16.0
#    7 │  2017    31.65         NaN           15.1
#    8 │  2018    35.0175       NaN           14.7
#    9 │  2019    37.48         NaN           13.7
#   10 │  2009    13.365         19.7        NaN
#   11 │  2010    14.38          19.7        NaN
#   ⋮  │   ⋮        ⋮          ⋮            ⋮
#   30 │  2001   NaN             25.0        NaN
#   31 │  2002   NaN             25.0        NaN
#   32 │  2003   NaN             25.0        NaN
#   33 │  2004   NaN             22.8        NaN
#   34 │  2005   NaN             23.7        NaN
#   35 │  2006   NaN             20.4        NaN
#   36 │  2007   NaN             20.0        NaN
#   37 │  2008   NaN             21.0        NaN
#   38 │  2021   NaN            NaN            9.2
#   39 │  2020   NaN            NaN           10.9
#                                   18 rows omitted

# %% [markdown]
# ### Wrangle NZ_health

# %%
using Query

columns_keep = ["CenYear", "EventCode", "StdRate", "SSex"] # define which columns we want
NZ_health = select(NZ_health, Symbol.(columns_keep)) # rewrite df as only the columns we want to work with
NZ_health
# Out:
# 72×4 DataFrame
#  Row │ CenYear  EventCode                          StdRate  SSex
#      │ Int64    String                             Float64  String
# ─────┼──────────────────────────────────────────────────────────────
#    1 │    1981  Cardiovascular Disease (all) Mor…    287.5  Males
#    2 │    1986  Cardiovascular Disease (all) Mor…    249.8  Males
#    3 │    1991  Cardiovascular Disease (all) Mor…    208.0  Males
#    4 │    1996  Cardiovascular Disease (all) Mor…    163.6  Males
#    5 │    2001  Cardiovascular Disease (all) Mor…    131.7  Males
#    6 │    2006  Cardiovascular Disease (all) Mor…     98.6  Males
#    7 │    1981  Cardiovascular Disease (all) Mor…    144.8  Females
#    8 │    1986  Cardiovascular Disease (all) Mor…    120.8  Females
#    9 │    1991  Cardiovascular Disease (all) Mor…     97.7  Females
#   10 │    1996  Cardiovascular Disease (all) Mor…     75.6  Females
#   11 │    2001  Cardiovascular Disease (all) Mor…     64.7  Females
#   ⋮  │    ⋮                     ⋮                     ⋮        ⋮
#   63 │    1991  External Injuries (All) Mortality     69.9  Males
#   64 │    1996  External Injuries (All) Mortality     64.3  Males
#   65 │    2001  External Injuries (All) Mortality     52.0  Males
#   66 │    2006  External Injuries (All) Mortality     47.3  Males
#   67 │    1981  External Injuries (All) Mortality     24.2  Females
#   68 │    1986  External Injuries (All) Mortality     24.6  Females
#   69 │    1991  External Injuries (All) Mortality     21.6  Females
#   70 │    1996  External Injuries (All) Mortality     19.8  Females
#   71 │    2001  External Injuries (All) Mortality     18.0  Females
#   72 │    2006  External Injuries (All) Mortality     16.0  Females
#                                                      51 rows omitted

# %%
values = ["External Injuries (All) Mortality", "Infectious Diseases Mortality"] # define values to remove 
filter!(row -> !(row.EventCode in values), NZ_health) # remove causes of death unreleated to smoking
# Out:
# 48×4 DataFrame
#  Row │ CenYear  EventCode                          StdRate  SSex
#      │ Int64    String                             Float64  String
# ─────┼──────────────────────────────────────────────────────────────
#    1 │    1981  Cardiovascular Disease (all) Mor…    287.5  Males
#    2 │    1986  Cardiovascular Disease (all) Mor…    249.8  Males
#    3 │    1991  Cardiovascular Disease (all) Mor…    208.0  Males
#    4 │    1996  Cardiovascular Disease (all) Mor…    163.6  Males
#    5 │    2001  Cardiovascular Disease (all) Mor…    131.7  Males
#    6 │    2006  Cardiovascular Disease (all) Mor…     98.6  Males
#    7 │    1981  Cardiovascular Disease (all) Mor…    144.8  Females
#    8 │    1986  Cardiovascular Disease (all) Mor…    120.8  Females
#    9 │    1991  Cardiovascular Disease (all) Mor…     97.7  Females
#   10 │    1996  Cardiovascular Disease (all) Mor…     75.6  Females
#   11 │    2001  Cardiovascular Disease (all) Mor…     64.7  Females
#   ⋮  │    ⋮                     ⋮                     ⋮        ⋮
#   39 │    1991  Diabetes Mortality                    12.7  Males
#   40 │    1996  Diabetes Mortality                    15.4  Males
#   41 │    2001  Diabetes Mortality                    18.2  Males
#   42 │    2006  Diabetes Mortality                    15.0  Males
#   43 │    1981  Diabetes Mortality                     9.8  Females
#   44 │    1986  Diabetes Mortality                     9.4  Females
#   45 │    1991  Diabetes Mortality                    10.9  Females
#   46 │    1996  Diabetes Mortality                    11.3  Females
#   47 │    2001  Diabetes Mortality                    11.7  Females
#   48 │    2006  Diabetes Mortality                     8.6  Females
#                                                      27 rows omitted

# %%
unique(NZ_health.EventCode) # check what causes of death remain
# Out:
# 4-element Vector{String}:
#  "Cardiovascular Disease (all) Mortality"
#  "Cancer (all) Mortality"
#  "Respiratory (all) Mortality"
#  "Diabetes Mortality"

# %%
NZ_health.StdRate .= NZ_health.StdRate ./ 10 # convert rate from per 100,000 to per 1,000,000 to plot on same graph as other variables and share same axis
# Out:
# 48-element Vector{Float64}:
#  28.75
#  24.98
#  20.8
#  16.36
#  13.169999999999998
#   9.86
#  14.48
#  12.08
#   9.77
#   7.56
#   6.470000000000001
#   4.64
#  15.6
#   ⋮
#   1.16
#   1.22
#   1.27
#   1.54
#   1.8199999999999998
#   1.5
#   0.9800000000000001
#   0.9400000000000001
#   1.09
#   1.1300000000000001
#   1.17
#   0.86

# %%
grouped = combine(groupby(NZ_health, [:CenYear, :EventCode]), :StdRate => mean) # average male and female data per year/event
# Out:
# 24×3 DataFrame
#  Row │ CenYear  EventCode                          StdRate_mean
#      │ Int64    String                             Float64
# ─────┼──────────────────────────────────────────────────────────
#    1 │    1981  Cardiovascular Disease (all) Mor…        21.615
#    2 │    1986  Cardiovascular Disease (all) Mor…        18.53
#    3 │    1991  Cardiovascular Disease (all) Mor…        15.285
#    4 │    1996  Cardiovascular Disease (all) Mor…        11.96
#    5 │    2001  Cardiovascular Disease (all) Mor…         9.82
#    6 │    2006  Cardiovascular Disease (all) Mor…         7.25
#    7 │    1981  Cancer (all) Mortality                   13.73
#    8 │    1986  Cancer (all) Mortality                   13.6
#    9 │    1991  Cancer (all) Mortality                   13.45
#   10 │    1996  Cancer (all) Mortality                   13.165
#   11 │    2001  Cancer (all) Mortality                   13.075
#   ⋮  │    ⋮                     ⋮                       ⋮
#   15 │    1991  Respiratory (all) Mortality               2.325
#   16 │    1996  Respiratory (all) Mortality               2.175
#   17 │    2001  Respiratory (all) Mortality               2.165
#   18 │    2006  Respiratory (all) Mortality               1.775
#   19 │    1981  Diabetes Mortality                        1.07
#   20 │    1986  Diabetes Mortality                        1.08
#   21 │    1991  Diabetes Mortality                        1.18
#   22 │    1996  Diabetes Mortality                        1.335
#   23 │    2001  Diabetes Mortality                        1.495
#   24 │    2006  Diabetes Mortality                        1.18
#                                                   3 rows omitted

# %%
NZ_health_wide = unstack(grouped, :EventCode, :StdRate_mean) # make dataframe wide
rename!(NZ_health_wide, [:Year, :cardiovascular, :cancer, :respiratory, :diabetes]) # rename columns
# Out:
# 6×5 DataFrame
#  Row │ Year   cardiovascular  cancer    respiratory  diabetes
#      │ Int64  Float64?        Float64?  Float64?     Float64?
# ─────┼────────────────────────────────────────────────────────
#    1 │  1981          21.615    13.73         3.115     1.07
#    2 │  1986          18.53     13.6          2.91      1.08
#    3 │  1991          15.285    13.45         2.325     1.18
#    4 │  1996          11.96     13.165        2.175     1.335
#    5 │  2001           9.82     13.075        2.165     1.495
#    6 │  2006           7.25     11.645        1.775     1.18

# %% [markdown]
# ## Join tables

# %%
joined_df_3 = innerjoin(NZ_health_wide, joined_df, on = :Year) # join tables on year column. Inner join to keep only years that have the health information.
select!(joined_df_3, Not([:cost_mean])) # no values for these years
# Out:
# 5×6 DataFrame
#  Row │ Year   cardiovascular  cancer    respiratory  diabetes  prev_float
#      │ Int64  Float64?        Float64?  Float64?     Float64?  Float64
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │  1986          18.53     13.6          2.91      1.08         30.0
#    2 │  1991          15.285    13.45         2.325     1.18         25.8
#    3 │  1996          11.96     13.165        2.175     1.335        26.0
#    4 │  2001           9.82     13.075        2.165     1.495        25.0
#    5 │  2006           7.25     11.645        1.775     1.18         20.4

# %% [markdown]
# ## Plots before joining data to fact table

# %%
using Plots

y = [joined_df_2.cost_mean, joined_df_2.prev_float, joined_df_2.recent_prev]
plot(joined_df_2.Year, y, seriestype=:line, label=["Average cost 25 pack" "Smoking prevalence 1983-2017" "Smoking prevalence 2011-2021"], 
    title="Cost of cigarettes and prevalence of smoking in NZ", ylabel="Cost (NZD) / Prevalence (%)", xlabel="Year", 
    legend=:bottomleft, lw=2, arrow = :arrow, size = (600, 400))

#savefig("NZ_prev_cost_1983-2021.png") # save the plot to file

# %%
filtered_df_1 = filter(row -> row.Year >= 2009, joined_df_2) # filter to only include years where there is cost data (i.e. 2009+)
# Out:
# 13×4 DataFrame
#  Row │ Year   cost_mean  prev_float  recent_prev
#      │ Int64  Float64    Float64     Float64
# ─────┼───────────────────────────────────────────
#    1 │  2011    16.39          18.4         18.4
#    2 │  2012    18.46          17.6         17.9
#    3 │  2013    20.79          17.4         17.6
#    4 │  2014    23.0725        16.6         16.8
#    5 │  2015    26.425         16.3         16.6
#    6 │  2016    28.805         15.7         16.0
#    7 │  2017    31.65         NaN           15.1
#    8 │  2018    35.0175       NaN           14.7
#    9 │  2019    37.48         NaN           13.7
#   10 │  2009    13.365         19.7        NaN
#   11 │  2010    14.38          19.7        NaN
#   12 │  2021   NaN            NaN            9.2
#   13 │  2020   NaN            NaN           10.9

# %%
using Plots

y = [filtered_df_1.cost_mean, filtered_df_1.prev_float, filtered_df_1.recent_prev]
plot(filtered_df_1.Year, y, seriestype=:line, label=["Average cost 25 pack" "Smoking prevalence 1983-2017" "Smoking prevalence 2011-2021"], 
    title="Cost of cigarettes and prevalence of smoking in NZ", ylabel="Cost (NZD) / Prevalence (%)", xlabel="Year", 
    legend=:topleft, lw=2, arrow = :arrow, size = (600, 400), ylims=(0, 40), xlims=(2008, 2022))

#savefig("NZ_prev_cost_2009-2021.png")

## year is a float on graph despite being int in df??
## setting xlims fixed float issue, but 2022 gets cut off on the axis? No change with resizing plot.
## ylims set to start at 0 doesn't look as pretty as the default range

# %%
joined_df_3[!, :total_rate] = joined_df_3.cardiovascular + joined_df_3.diabetes + joined_df_3.cancer + joined_df_3.respiratory # calculate the total rate of mortality for the 4 types

joined_df_3
# Out:
# 5×7 DataFrame
#  Row │ Year   cardiovascular  cancer    respiratory  diabetes  prev_float  tot ⋯
#      │ Int64  Float64?        Float64?  Float64?     Float64?  Float64     Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  1986          18.53     13.6          2.91      1.08         30.0      ⋯
#    2 │  1991          15.285    13.45         2.325     1.18         25.8
#    3 │  1996          11.96     13.165        2.175     1.335        26.0
#    4 │  2001           9.82     13.075        2.165     1.495        25.0
#    5 │  2006           7.25     11.645        1.775     1.18         20.4      ⋯
#                                                                 1 column omitted

# %%
y_prev = joined_df_3.prev_float
y_cardiovascular = joined_df_3.cardiovascular
y_cancer = joined_df_3.cancer
y_respiratory = joined_df_3.respiratory
y_diabetes = joined_df_3.diabetes
y_total = joined_df_3.total_rate

plot(
    joined_df_3.Year, y_prev, seriestype=:line, label="Smoking Prevalence",
    title="NZ prevalence of smoking and rates of \nmortality from associated illnesses 1986-2006",
    titlefont = font(11),
    ylabel="Prevalence (%) / Rate (per million)", xlabel="Year", arrow = :arrow,
    legend=:outerbottom, legendfontsize=7, legendcolumns=2, 
    lw=3, linestyle=:dashdotdot, size=(600, 500)
)
plot!(
    joined_df_3.Year, y_total, seriestype=:line, lw=3, label="Total death rate of associated illnesses", arrow = :arrow,
   )
plot!(
    joined_df_3.Year, y_cardiovascular, seriestype=:line, lw=3, label="Cardiovascular Disease", arrow = :arrow,
    )
plot!(
    joined_df_3.Year, y_cancer, seriestype=:line, lw=3, label="Cancer", arrow = :arrow,
    )
plot!(
    joined_df_3.Year, y_respiratory, seriestype=:line, lw=3, label="Respiratory", arrow = :arrow,
    )
plot!(
    joined_df_3.Year, y_diabetes, seriestype=:line, lw=3, label="Diabetes", arrow = :arrow,
   )

#savefig("NZ_prevalence_mortality.png")

# %% [markdown]
# ## Preparing NZ data for joining to fact_table in R
# #### (as it proved too difficult to do here in Julia with missing, "missing", NA values).

# %%
joined_df_2.CountryCode = fill("NZL", nrow(joined_df_2)) # create new column for country to match fact table 
joined_df_2.GenderCode = fill("BTSX", nrow(joined_df_2)) # new column for gender

joined_df_2
# Out:
# 39×6 DataFrame
#  Row │ Year   cost_mean  prev_float  recent_prev  CountryCode  GenderCode
#      │ Int64  Float64    Float64     Float64      String       String
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │  2011    16.39          18.4         18.4  NZL          BTSX
#    2 │  2012    18.46          17.6         17.9  NZL          BTSX
#    3 │  2013    20.79          17.4         17.6  NZL          BTSX
#    4 │  2014    23.0725        16.6         16.8  NZL          BTSX
#    5 │  2015    26.425         16.3         16.6  NZL          BTSX
#    6 │  2016    28.805         15.7         16.0  NZL          BTSX
#    7 │  2017    31.65         NaN           15.1  NZL          BTSX
#    8 │  2018    35.0175       NaN           14.7  NZL          BTSX
#    9 │  2019    37.48         NaN           13.7  NZL          BTSX
#   10 │  2009    13.365         19.7        NaN    NZL          BTSX
#   11 │  2010    14.38          19.7        NaN    NZL          BTSX
#   ⋮  │   ⋮        ⋮          ⋮            ⋮            ⋮           ⋮
#   30 │  2001   NaN             25.0        NaN    NZL          BTSX
#   31 │  2002   NaN             25.0        NaN    NZL          BTSX
#   32 │  2003   NaN             25.0        NaN    NZL          BTSX
#   33 │  2004   NaN             22.8        NaN    NZL          BTSX
#   34 │  2005   NaN             23.7        NaN    NZL          BTSX
#   35 │  2006   NaN             20.4        NaN    NZL          BTSX
#   36 │  2007   NaN             20.0        NaN    NZL          BTSX
#   37 │  2008   NaN             21.0        NaN    NZL          BTSX
#   38 │  2021   NaN            NaN            9.2  NZL          BTSX
#   39 │  2020   NaN            NaN           10.9  NZL          BTSX
#                                                            18 rows omitted

# %%
function custom_average(x, y)
    if isnan(x) # if x is NaN, value is y
        y
    elseif isnan(y) # if y is NaN, value is x
        x
    else
        (x + y) / 2 # if neither are NaN, value is average of the two
    end
end

# Calculate the average for 'prev_float' and 'recent_prev' using the custom function above and create new column for the result
joined_df_2.AveragePrev = [custom_average(x, y) for (x, y) in zip(joined_df_2.prev_float, joined_df_2.recent_prev)]

joined_df_2
# Out:
# 39×7 DataFrame
#  Row │ Year   cost_mean  prev_float  recent_prev  CountryCode  GenderCode  Ave ⋯
#      │ Int64  Float64    Float64     Float64      String       String      Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  2011    16.39          18.4         18.4  NZL          BTSX            ⋯
#    2 │  2012    18.46          17.6         17.9  NZL          BTSX
#    3 │  2013    20.79          17.4         17.6  NZL          BTSX
#    4 │  2014    23.0725        16.6         16.8  NZL          BTSX
#    5 │  2015    26.425         16.3         16.6  NZL          BTSX            ⋯
#    6 │  2016    28.805         15.7         16.0  NZL          BTSX
#    7 │  2017    31.65         NaN           15.1  NZL          BTSX
#    8 │  2018    35.0175       NaN           14.7  NZL          BTSX
#    9 │  2019    37.48         NaN           13.7  NZL          BTSX            ⋯
#   10 │  2009    13.365         19.7        NaN    NZL          BTSX
#   11 │  2010    14.38          19.7        NaN    NZL          BTSX
#   ⋮  │   ⋮        ⋮          ⋮            ⋮            ⋮           ⋮           ⋱
#   30 │  2001   NaN             25.0        NaN    NZL          BTSX
#   31 │  2002   NaN             25.0        NaN    NZL          BTSX            ⋯
#   32 │  2003   NaN             25.0        NaN    NZL          BTSX
#   33 │  2004   NaN             22.8        NaN    NZL          BTSX
#   34 │  2005   NaN             23.7        NaN    NZL          BTSX
#   35 │  2006   NaN             20.4        NaN    NZL          BTSX            ⋯
#   36 │  2007   NaN             20.0        NaN    NZL          BTSX
#   37 │  2008   NaN             21.0        NaN    NZL          BTSX
#   38 │  2021   NaN            NaN            9.2  NZL          BTSX
#   39 │  2020   NaN            NaN           10.9  NZL          BTSX            ⋯
#                                                     1 column and 18 rows omitted

# %%
select!(joined_df_2, Not([:recent_prev, :prev_float])) # remove unwanted prevalence columns that have been averaged
# Out:
# 39×5 DataFrame
#  Row │ Year   cost_mean  CountryCode  GenderCode  AveragePrev
#      │ Int64  Float64    String       String      Float64
# ─────┼────────────────────────────────────────────────────────
#    1 │  2011    16.39    NZL          BTSX              18.4
#    2 │  2012    18.46    NZL          BTSX              17.75
#    3 │  2013    20.79    NZL          BTSX              17.5
#    4 │  2014    23.0725  NZL          BTSX              16.7
#    5 │  2015    26.425   NZL          BTSX              16.45
#    6 │  2016    28.805   NZL          BTSX              15.85
#    7 │  2017    31.65    NZL          BTSX              15.1
#    8 │  2018    35.0175  NZL          BTSX              14.7
#    9 │  2019    37.48    NZL          BTSX              13.7
#   10 │  2009    13.365   NZL          BTSX              19.7
#   11 │  2010    14.38    NZL          BTSX              19.7
#   ⋮  │   ⋮        ⋮           ⋮           ⋮            ⋮
#   30 │  2001   NaN       NZL          BTSX              25.0
#   31 │  2002   NaN       NZL          BTSX              25.0
#   32 │  2003   NaN       NZL          BTSX              25.0
#   33 │  2004   NaN       NZL          BTSX              22.8
#   34 │  2005   NaN       NZL          BTSX              23.7
#   35 │  2006   NaN       NZL          BTSX              20.4
#   36 │  2007   NaN       NZL          BTSX              20.0
#   37 │  2008   NaN       NZL          BTSX              21.0
#   38 │  2021   NaN       NZL          BTSX               9.2
#   39 │  2020   NaN       NZL          BTSX              10.9
#                                                18 rows omitted

# %%
#CSV.write("nz_data.csv", joined_df_2) # save to use file in R to merge with WHO data

# %% [markdown]
# ## Work with new fact table after NZ data added

# %%
fact_table = CSV.read("fact-table.csv", DataFrame) # fact table of WHO data that had been wrangled in R and NZ data added in
# Out:
# 12660×11 DataFrame
#    Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpe ⋯
#        │ String    String       Int64  String      String             String   ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ BDI2000B  BDI           2000  BTSX        24                 43.78    ⋯
#      2 │ BDI2000F  BDI           2000  FMLE        16.4               45.85
#      3 │ BDI2000M  BDI           2000  MLE         31.5               41.79
#      4 │ BDI2005B  BDI           2005  BTSX        19.8               NA
#      5 │ BDI2005F  BDI           2005  FMLE        12.7               NA       ⋯
#      6 │ BDI2005M  BDI           2005  MLE         26.9               NA
#      7 │ BDI2010B  BDI           2010  BTSX        16.6               58.6
#      8 │ BDI2010F  BDI           2010  FMLE        9.9                60.32
#      9 │ BDI2010M  BDI           2010  MLE         23.3               56.86    ⋯
#     10 │ BDI2015B  BDI           2015  BTSX        13.9               62.05
#     11 │ BDI2015F  BDI           2015  FMLE        7.8                64.26
#    ⋮   │    ⋮           ⋮         ⋮        ⋮               ⋮                ⋮  ⋱
#  12651 │ NZL1991B  NZL           1991  BTSX        25.8               NA
#  12652 │ NZL1992B  NZL           1992  BTSX        27                 NA       ⋯
#  12653 │ NZL1993B  NZL           1993  BTSX        27                 NA
#  12654 │ NZL1994B  NZL           1994  BTSX        27                 NA
#  12655 │ NZL1995B  NZL           1995  BTSX        27                 NA
#  12656 │ NZL1996B  NZL           1996  BTSX        26                 NA       ⋯
#  12657 │ NZL1997B  NZL           1997  BTSX        26                 NA
#  12658 │ NZL1998B  NZL           1998  BTSX        25                 NA
#  12659 │ NZL1999B  NZL           1999  BTSX        26                 NA
#  12660 │ NZL2021B  NZL           2021  BTSX        9.2                NA       ⋯
#                                                 6 columns and 12639 rows omitted

# %%
NZL_df = filter(row -> row.CountryCode == "NZL" && row.GenderCode == "BTSX", fact_table) # create new df of only NZ data from fact table
# Out:
# 41×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      String             String     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2000B  NZL           2000  BTSX        25                 78.57      ⋯
#    2 │ NZL2005B  NZL           2005  BTSX        23.7               NA
#    3 │ NZL2010B  NZL           2010  BTSX        19.7               80.94
#    4 │ NZL2015B  NZL           2015  BTSX        16.45              81.31
#    5 │ NZL2018B  NZL           2018  BTSX        14.7               NA         ⋯
#    6 │ NZL2019B  NZL           2019  BTSX        13.7               81.96
#    7 │ NZL2020B  NZL           2020  BTSX        10.9               NA
#    8 │ NZL2023B  NZL           2023  BTSX        NA                 NA
#    9 │ NZL2025B  NZL           2025  BTSX        11.2               NA         ⋯
#   10 │ NZL2001B  NZL           2001  BTSX        25                 NA
#   11 │ NZL2002B  NZL           2002  BTSX        25                 NA
#   ⋮  │    ⋮           ⋮         ⋮        ⋮               ⋮                ⋮    ⋱
#   32 │ NZL1991B  NZL           1991  BTSX        25.8               NA
#   33 │ NZL1992B  NZL           1992  BTSX        27                 NA         ⋯
#   34 │ NZL1993B  NZL           1993  BTSX        27                 NA
#   35 │ NZL1994B  NZL           1994  BTSX        27                 NA
#   36 │ NZL1995B  NZL           1995  BTSX        27                 NA
#   37 │ NZL1996B  NZL           1996  BTSX        26                 NA         ⋯
#   38 │ NZL1997B  NZL           1997  BTSX        26                 NA
#   39 │ NZL1998B  NZL           1998  BTSX        25                 NA
#   40 │ NZL1999B  NZL           1999  BTSX        26                 NA
#   41 │ NZL2021B  NZL           2021  BTSX        9.2                NA         ⋯
#                                                    6 columns and 20 rows omitted

# %%
columns = [:MediumPriceEstTobacco, :TobaccoPrevalence, :LifeExpectancy, :Mortality, :LowestPricEstTobacco, :PremiumPricEstTobacco, :TotalTax]

for col in columns
    NZL_df[!, col] = [custom_parse_float(x) for x in NZL_df[!, col]] # convert to float and replace NA with NaN using previously defined function
end

NZL_df
# Out:
# 41×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2000B  NZL           2000  BTSX                    25.0            7 ⋯
#    2 │ NZL2005B  NZL           2005  BTSX                    23.7           Na
#    3 │ NZL2010B  NZL           2010  BTSX                    19.7            8
#    4 │ NZL2015B  NZL           2015  BTSX                    16.45           8
#    5 │ NZL2018B  NZL           2018  BTSX                    14.7           Na ⋯
#    6 │ NZL2019B  NZL           2019  BTSX                    13.7            8
#    7 │ NZL2020B  NZL           2020  BTSX                    10.9           Na
#    8 │ NZL2023B  NZL           2023  BTSX                   NaN             Na
#    9 │ NZL2025B  NZL           2025  BTSX                    11.2           Na ⋯
#   10 │ NZL2001B  NZL           2001  BTSX                    25.0           Na
#   11 │ NZL2002B  NZL           2002  BTSX                    25.0           Na
#   ⋮  │    ⋮           ⋮         ⋮        ⋮               ⋮                ⋮    ⋱
#   32 │ NZL1991B  NZL           1991  BTSX                    25.8           Na
#   33 │ NZL1992B  NZL           1992  BTSX                    27.0           Na ⋯
#   34 │ NZL1993B  NZL           1993  BTSX                    27.0           Na
#   35 │ NZL1994B  NZL           1994  BTSX                    27.0           Na
#   36 │ NZL1995B  NZL           1995  BTSX                    27.0           Na
#   37 │ NZL1996B  NZL           1996  BTSX                    26.0           Na ⋯
#   38 │ NZL1997B  NZL           1997  BTSX                    26.0           Na
#   39 │ NZL1998B  NZL           1998  BTSX                    25.0           Na
#   40 │ NZL1999B  NZL           1999  BTSX                    26.0           Na
#   41 │ NZL2021B  NZL           2021  BTSX                     9.2           Na ⋯
#                                                    6 columns and 20 rows omitted

# %%
y = [NZL_df.TobaccoPrevalence, NZL_df.MediumPriceEstTobacco]
plot(NZL_df.Year, y, seriestype=:line, label=["Smoking prevalence" "Cost"], 
    title="Cost of cigarettes and prevalence of smoking in NZ", ylabel="Cost (NZD) / Prevalence (%)", xlabel="Year", 
    legend=:bottomleft, lw=2, arrow = :arrow, size = (600, 400))

#filter out 2020. The 2020 value for cost was a WHO value, rather than StatsNZ value, thus not measuring the same way

# %%
NZL_df[7, :MediumPriceEstTobacco] = NaN # remove value by setting it to missing
# Out:
# NaN

# %%
filtered_nzl = filter(row -> row.Year >= 2009, NZL_df) # filter for years from 2009 (the years we have cost data for)
# Out:
# 15×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2010B  NZL           2010  BTSX                    19.7            8 ⋯
#    2 │ NZL2015B  NZL           2015  BTSX                    16.45           8
#    3 │ NZL2018B  NZL           2018  BTSX                    14.7           Na
#    4 │ NZL2019B  NZL           2019  BTSX                    13.7            8
#    5 │ NZL2020B  NZL           2020  BTSX                    10.9           Na ⋯
#    6 │ NZL2023B  NZL           2023  BTSX                   NaN             Na
#    7 │ NZL2025B  NZL           2025  BTSX                    11.2           Na
#    8 │ NZL2009B  NZL           2009  BTSX                    19.7           Na
#    9 │ NZL2011B  NZL           2011  BTSX                    18.4           Na ⋯
#   10 │ NZL2012B  NZL           2012  BTSX                    17.75          Na
#   11 │ NZL2013B  NZL           2013  BTSX                    17.5           Na
#   12 │ NZL2014B  NZL           2014  BTSX                    16.7           Na
#   13 │ NZL2016B  NZL           2016  BTSX                    15.85          Na ⋯
#   14 │ NZL2017B  NZL           2017  BTSX                    15.1           Na
#   15 │ NZL2021B  NZL           2021  BTSX                     9.2           Na
#                                                                6 columns omitted

# %%
y = [filtered_nzl.TobaccoPrevalence, filtered_nzl.MediumPriceEstTobacco]
plot(filtered_nzl.Year, y, seriestype=:line, label=["Smoking prevalence" "Cost"], 
    title="Prevalence of Smoking and Cost of Cigarettes in NZ", ylabel="Cost (NZD) / Prevalence (%)", xlabel="Year", 
    legend=:topleft, lw=2, arrow = :arrow, size = (600, 400), ylims=(0, 40), xlims=(2008, 2022))

# %%
y_life = NZL_df.LifeExpectancy
y_mort = NZL_df.Mortality
y_cost = NZL_df.MediumPriceEstTobacco
y_prev = NZL_df.TobaccoPrevalence

plot(
    NZL_df.Year, y_cost, seriestype=:line, label="Cost",
    title="title",
    ylabel="y", xlabel="Year",
    legend=:left, lw=3, size=(600, 400), arrow = :arrow, ylims=(0, 90), xlims=(1982, 2023),
)
plot!(
    NZL_df.Year, y_prev, seriestype=:line, lw=3, label="Smoking prevalence", arrow = :arrow,
   )
plot!(
    NZL_df.Year, y_mort, seriestype=:line, lw=3, label="Mortality rate", arrow = :arrow,
   )
plot!(
    NZL_df.Year, y_life, seriestype=:scatter, lw=3, label="Life expectancy",
   )

# can't plot life expectancy due to missing values?

# %%
filtered_nzl_life = filter(row -> row.Year >= 2000, NZL_df) # filter for years from 2000
# Out:
# 24×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2000B  NZL           2000  BTSX                    25.0            7 ⋯
#    2 │ NZL2005B  NZL           2005  BTSX                    23.7           Na
#    3 │ NZL2010B  NZL           2010  BTSX                    19.7            8
#    4 │ NZL2015B  NZL           2015  BTSX                    16.45           8
#    5 │ NZL2018B  NZL           2018  BTSX                    14.7           Na ⋯
#    6 │ NZL2019B  NZL           2019  BTSX                    13.7            8
#    7 │ NZL2020B  NZL           2020  BTSX                    10.9           Na
#    8 │ NZL2023B  NZL           2023  BTSX                   NaN             Na
#    9 │ NZL2025B  NZL           2025  BTSX                    11.2           Na ⋯
#   10 │ NZL2001B  NZL           2001  BTSX                    25.0           Na
#   11 │ NZL2002B  NZL           2002  BTSX                    25.0           Na
#   ⋮  │    ⋮           ⋮         ⋮        ⋮               ⋮                ⋮    ⋱
#   15 │ NZL2007B  NZL           2007  BTSX                    20.0           Na
#   16 │ NZL2008B  NZL           2008  BTSX                    21.0           Na ⋯
#   17 │ NZL2009B  NZL           2009  BTSX                    19.7           Na
#   18 │ NZL2011B  NZL           2011  BTSX                    18.4           Na
#   19 │ NZL2012B  NZL           2012  BTSX                    17.75          Na
#   20 │ NZL2013B  NZL           2013  BTSX                    17.5           Na ⋯
#   21 │ NZL2014B  NZL           2014  BTSX                    16.7           Na
#   22 │ NZL2016B  NZL           2016  BTSX                    15.85          Na
#   23 │ NZL2017B  NZL           2017  BTSX                    15.1           Na
#   24 │ NZL2021B  NZL           2021  BTSX                     9.2           Na ⋯
#                                                     6 columns and 3 rows omitted

# %%
y_mort = filtered_nzl_life.Mortality
y_cost = filtered_nzl_life.MediumPriceEstTobacco
y_prev = filtered_nzl_life.TobaccoPrevalence

plot(
    filtered_nzl_life.Year, y_cost, seriestype=:line, label="Cost of cigarettes",
    title="Changes in Cost of Cigarettes, Smoking Prevalence,\nand Mortality Rate in NZ",
    titlefont = font(11),
    ylabel="Cost (NZD) / Rate (%)", xlabel="Year", marker=:circle,
    legend=:bottomleft, lw=3, size= (600, 400),  ylims=(0, 40), xlims=(1999, 2021),
)
plot!(
    filtered_nzl_life.Year, y_prev, seriestype=:line, lw=3, label="Smoking prevalence", marker=:circle,
   )
plot!(
    filtered_nzl_life.Year, y_mort, seriestype=:line, lw=3, label="Mortality rate", marker=:circle,
   )

# only plotting 4 points/years - unsure why? Troubleshooted below by creating new df.

# %%
filter!(row -> !isnan(row.LifeExpectancy), filtered_nzl_life) # remove rows where life expectancy is NaN so can plot lines
# Out:
# 4×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2000B  NZL           2000  BTSX                    25.0            7 ⋯
#    2 │ NZL2010B  NZL           2010  BTSX                    19.7            8
#    3 │ NZL2015B  NZL           2015  BTSX                    16.45           8
#    4 │ NZL2019B  NZL           2019  BTSX                    13.7            8
#                                                                6 columns omitted

# %%
y_life = filtered_nzl_life.LifeExpectancy
y_mort = filtered_nzl_life.Mortality
y_cost = filtered_nzl_life.MediumPriceEstTobacco
y_prev = filtered_nzl_life.TobaccoPrevalence

plot(
    filtered_nzl_life.Year, y_cost, seriestype=:line, label="Cost (NZD)",
    title="Changes in Cost of Cigarettes, Smoking Prevalence,\nMortality Rate and Life Expectancy in NZ",
    titlefont = font(11),
    ylabel="", xlabel="Year",
    legend=:left,legendcolumns=1, 
    lw=3, marker=:circle, size=(600, 400), ylims=(0, 90), xlims=(1999, 2021), 
)
plot!(
    filtered_nzl_life.Year, y_prev, seriestype=:line, lw=3, label="Smoking prevalence (%)", marker=:circle,
   )
plot!(
    filtered_nzl_life.Year, y_mort, seriestype=:line, lw=3, label="Mortality rate (%)", marker=:circle,
   )
plot!(
    filtered_nzl_life.Year, y_life, seriestype=:line, lw=3, label="Life expectancy (years)", marker=:circle,                     
   )

#savefig("NZ_cost_prevalence_mortality_lifeexp.png")

# %%
filtered_tax = filter(row -> !isnan(row.MediumPriceEstTobacco) && !isnan(row.TotalTax), NZL_df) # remove rows where cost and tax are NaN so can calculate tax amount
filtered_tax
# Out:
# 6×11 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2010B  NZL           2010  BTSX                    19.7            8 ⋯
#    2 │ NZL2018B  NZL           2018  BTSX                    14.7           Na
#    3 │ NZL2008B  NZL           2008  BTSX                    21.0           Na
#    4 │ NZL2012B  NZL           2012  BTSX                    17.75          Na
#    5 │ NZL2014B  NZL           2014  BTSX                    16.7           Na ⋯
#    6 │ NZL2016B  NZL           2016  BTSX                    15.85          Na
#                                                                6 columns omitted

# %%
filtered_tax.cost_tax = filtered_tax.MediumPriceEstTobacco .* filtered_tax.TotalTax # calculating amount of tax

filtered_tax
# Out:
# 6×12 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  LifeExpect ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2010B  NZL           2010  BTSX                    19.7            8 ⋯
#    2 │ NZL2018B  NZL           2018  BTSX                    14.7           Na
#    3 │ NZL2008B  NZL           2008  BTSX                    21.0           Na
#    4 │ NZL2012B  NZL           2012  BTSX                    17.75          Na
#    5 │ NZL2014B  NZL           2014  BTSX                    16.7           Na ⋯
#    6 │ NZL2016B  NZL           2016  BTSX                    15.85          Na
#                                                                7 columns omitted

# %%
y = [filtered_tax.MediumPriceEstTobacco, filtered_tax.cost_tax]
plot(filtered_tax.Year, y, seriestype=:line, label=["Average total cost 25 pack" "Amount of tax"], 
    title="Cost of cigarettes and amount of tax per pack", ylabel="Cost (NZD)", xlabel="Year", 
    legend=:topleft, lw=2, arrow = :arrow, size = (600, 400), ylims=(0, 40), xlims=(2008, 2018))

# %%
filtered_nzl_life_2 = filter(row -> row.Year >= 2000, NZL_df) # filter for years from 2000 
select!(filtered_nzl_life_2, Not([:TotalTax, :PremiumPricEstTobacco, :LowestPricEstTobacco, :LifeExpectancy])) # remove unwanted columns
# to see if this allows us to plot more points that just 4 years!
# Out:
# 24×7 DataFrame
#  Row │ ID        CountryCode  Year   GenderCode  TobaccoPrevalence  Mortality  ⋯
#      │ String    String       Int64  String      Float64            Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NZL2000B  NZL           2000  BTSX                    25.0       15.92  ⋯
#    2 │ NZL2005B  NZL           2005  BTSX                    23.7       13.3
#    3 │ NZL2010B  NZL           2010  BTSX                    19.7       11.79
#    4 │ NZL2015B  NZL           2015  BTSX                    16.45      10.91
#    5 │ NZL2018B  NZL           2018  BTSX                    14.7       10.41  ⋯
#    6 │ NZL2019B  NZL           2019  BTSX                    13.7       10.26
#    7 │ NZL2020B  NZL           2020  BTSX                    10.9      NaN
#    8 │ NZL2023B  NZL           2023  BTSX                   NaN        NaN
#    9 │ NZL2025B  NZL           2025  BTSX                    11.2      NaN     ⋯
#   10 │ NZL2001B  NZL           2001  BTSX                    25.0       15.78
#   11 │ NZL2002B  NZL           2002  BTSX                    25.0       15.16
#   ⋮  │    ⋮           ⋮         ⋮        ⋮               ⋮              ⋮      ⋱
#   15 │ NZL2007B  NZL           2007  BTSX                    20.0       12.98
#   16 │ NZL2008B  NZL           2008  BTSX                    21.0       12.33  ⋯
#   17 │ NZL2009B  NZL           2009  BTSX                    19.7       11.98
#   18 │ NZL2011B  NZL           2011  BTSX                    18.4       11.89
#   19 │ NZL2012B  NZL           2012  BTSX                    17.75      11.41
#   20 │ NZL2013B  NZL           2013  BTSX                    17.5       11.0   ⋯
#   21 │ NZL2014B  NZL           2014  BTSX                    16.7       10.81
#   22 │ NZL2016B  NZL           2016  BTSX                    15.85      10.77
#   23 │ NZL2017B  NZL           2017  BTSX                    15.1       10.94
#   24 │ NZL2021B  NZL           2021  BTSX                     9.2      NaN     ⋯
#                                                      1 column and 3 rows omitted

# %%
y_mort = filtered_nzl_life_2.Mortality
y_cost = filtered_nzl_life_2.MediumPriceEstTobacco
y_prev = filtered_nzl_life_2.TobaccoPrevalence

plot(
    filtered_nzl_life_2.Year, y_cost, seriestype=:line, label="Cost of cigarettes",
    title="Changes in Cost of Cigarettes, Smoking Prevalence,\nand Mortality Rate in NZ",
    titlefont = font(11),
    ylabel="Cost (NZD) / Rate (%)", xlabel="Year", marker=:circle,
    legend=:bottomleft, lw=3, size= (600, 400), ylims=(0, 40), xlims=(1999, 2021),
)
plot!(
    filtered_nzl_life_2.Year, y_prev, seriestype=:line, lw=3, label="Smoking prevalence", marker=:circle,
   )
plot!(
    filtered_nzl_life_2.Year, y_mort, seriestype=:line, lw=3, label="Mortality rate", marker=:circle,
   )

#savefig("NZ_cost_prevalence_mortality_2.png")
